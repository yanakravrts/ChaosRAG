# %%
import weaviate
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
from sklearn.decomposition import PCA
import os
from dotenv import load_dotenv

load_dotenv()

try:
    client = weaviate.connect_to_local(port=8079, grpc_port=50050)
except:
    client = weaviate.connect_to_embedded()
print("Connected to Weaviate Embedded")
# Out:
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"warning","log_level_env":"","msg":"log level not recognized, defaulting to info","time":"2026-01-18T18:13:59+02:00"}
# {"action":"startup","build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"Feature flag LD integration disabled: could not locate WEAVIATE_LD_API_KEY env variable","time":"2026-01-18T18:13:59+02:00"}
# {"action":"startup","build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","default_vectorizer_module":"none","level":"info","msg":"the default vectorizer modules is set to \"none\", as a result all new schema classes without an explicit vectorizer setting, will use this vectorizer","time":"2026-01-18T18:13:59+02:00"}
# {"action":"startup","auto_schema_enabled":{},"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"auto schema enabled setting is set to \"\u0026{\u003cnil\u003e {{{} {0 0}} 0 0 {{} 0} {{} 0}} true}\"","time":"2026-01-18T18:13:59+02:00"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"No resource limits set, weaviate will use all available memory and CPU. To limit resources, set LIMIT_RESOURCES=true","time":"2026-01-18T18:13:59+02:00"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"module offload-s3 is enabled","time":"2026-01-18T18:13:59+02:00"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","flag_key":"collection-retrieval-strategy","level":"info","msg":"feature flag instantiated","time":"2026-01-18T18:13:59+02:00","tool":"feature_flag","value":"LeaderOnly"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"warning","msg":"Multiple vector spaces are present, GraphQL Explore and REST API list objects endpoint module include params has been disabled as a result.","time":"2026-01-18T18:13:59+02:00"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"open cluster service","servers":{"Embedded_at_8079":62562},"time":"2026-01-18T18:13:59+02:00"}
# {"address":"192.168.1.17:62563","build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"starting cloud rpc server ...","time":"2026-01-18T18:13:59+02:00"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"starting raft sub-system ...","time":"2026-01-18T18:13:59+02:00"}
# {"address":"192.168.1.17:62562","build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"tcp transport","tcpMaxPool":3,"tcpTimeout":10000000000,"time":"2026-01-18T18:13:59+02:00"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"loading local db","time":"2026-01-18T18:13:59+02:00"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"local DB successfully loaded","time":"2026-01-18T18:13:59+02:00"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"schema manager loaded","n":0,"time":"2026-01-18T18:13:59+02:00"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","metadata_only_voters":false,"msg":"construct a new raft node","name":"Embedded_at_8079","time":"2026-01-18T18:13:59+02:00"}
# {"action":"raft","build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","index":12,"level":"info","msg":"initial configuration","servers":"[[{Suffrage:Voter ID:Embedded_at_8079 Address:192.168.1.15:51969}]]","time":"2026-01-18T18:13:59+02:00"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","last_snapshot_index":0,"last_store_applied_index_on_start":6,"level":"info","msg":"raft node constructed","raft_applied_index":0,"raft_last_index":12,"time":"2026-01-18T18:13:59+02:00"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","hasState":true,"level":"info","msg":"raft init","time":"2026-01-18T18:13:59+02:00"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"attempting to join","remoteNodes":{"Embedded_at_8079":"192.168.1.17:62562"},"time":"2026-01-18T18:13:59+02:00"}
# {"action":"raft","build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","follower":{},"leader-address":"","leader-id":"","level":"info","msg":"entering follower state","time":"2026-01-18T18:13:59+02:00"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"attempted to join and failed","remoteNode":"192.168.1.17:62562","status":8,"time":"2026-01-18T18:13:59+02:00"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"attempting to join","remoteNodes":{"Embedded_at_8079":"192.168.1.17:62562"},"time":"2026-01-18T18:14:00+02:00"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"attempted to join and failed","remoteNode":"192.168.1.17:62562","status":8,"time":"2026-01-18T18:14:00+02:00"}
# {"action":"raft","build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","last-leader-addr":"","last-leader-id":"","level":"warning","msg":"heartbeat timeout reached, starting election","time":"2026-01-18T18:14:00+02:00"}
# {"action":"raft","build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"entering candidate state","node":{},"term":6,"time":"2026-01-18T18:14:00+02:00"}
# {"action":"raft","build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"pre-vote successful, starting election","refused":0,"tally":1,"term":6,"time":"2026-01-18T18:14:00+02:00","votesNeeded":1}
# {"action":"raft","build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"election won","tally":1,"term":6,"time":"2026-01-18T18:14:00+02:00"}
# {"action":"raft","build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","leader":{},"level":"info","msg":"entering leader state","time":"2026-01-18T18:14:00+02:00"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","last_store_log_applied_index":6,"level":"info","log_index":6,"log_name":"LogCommand","log_type":0,"msg":"reloading local DB as RAFT and local DB are now caught up","time":"2026-01-18T18:14:00+02:00"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"reload local db: update schema ...","time":"2026-01-18T18:14:00+02:00"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","index":"ChaosKnowledgeBase","level":"info","msg":"reload local index","time":"2026-01-18T18:14:00+02:00"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"configured versions","server_version":"1.30.5","time":"2026-01-18T18:14:01+02:00","version":"1.30.5"}
# {"action":"grpc_startup","build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"grpc server listening at [::]:50050","time":"2026-01-18T18:14:01+02:00"}
# {"address":"192.168.1.17:62562","build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"current Leader","time":"2026-01-18T18:14:01+02:00"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"attempting to join","remoteNodes":{"Embedded_at_8079":"192.168.1.17:62562"},"time":"2026-01-18T18:14:01+02:00"}
# {"action":"raft","build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","command":0,"level":"info","msg":"updating configuration","server-addr":"192.168.1.17:62562","server-id":"Embedded_at_8079","servers":"[[{Suffrage:Voter ID:Embedded_at_8079 Address:192.168.1.17:62562}]]","time":"2026-01-18T18:14:01+02:00"}
# {"action":"restapi_management","build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"Serving weaviate at http://127.0.0.1:8079","time":"2026-01-18T18:14:01+02:00","version":"1.30.5"}
# Connected to Weaviate Embedded
# {"action":"hnsw_prefill_cache_async","build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"not waiting for vector cache prefill, running in background","time":"2026-01-18T18:14:01+02:00","wait_for_cache_prefill":false}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"Completed loading shard chaosknowledgebase_DrUXsU7vE0wr in 12.495458ms","time":"2026-01-18T18:14:01+02:00"}
# {"action":"hnsw_vector_cache_prefill","build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","count":3000,"index_id":"main","level":"info","limit":1000000000000,"msg":"prefilled vector cache","time":"2026-01-18T18:14:01+02:00","took":19783666}
# {"action":"telemetry_push","build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"telemetry started","payload":"\u0026{MachineID:f883c989-58b6-4e08-8e76-280a75da903c Type:INIT Version:1.30.5 ObjectsCount:0 OS:darwin Arch:arm64 UsedModules:[] CollectionsCount:1}","time":"2026-01-18T18:14:02+02:00"}

# %%
collection = client.collections.get("ChaosKnowledgeBase")

response = collection.query.fetch_objects(
    limit=2000,
    include_vector=True
)

data = []
for obj in response.objects:
    props = obj.properties
    data.append({
        "uuid": str(obj.uuid),
        "page": props.get("page"),
        "type": props.get("type", "image"), 
        "content_preview": props.get("text", "")[:100] + "...", 
        "vector": obj.vector["default"] 
    })

df = pd.DataFrame(data)
print(f"{len(df)} chunks")
df.head(10)
# Out:
# 678 chunks
#                                    uuid   page  type  \
# 0  0088b529-0cf7-45e8-a6aa-8aed46fb78b5   45.0  text
# 1  00ccc42e-1098-4e59-a35c-e0f72ff6f598  216.0  text
# 2  011c6524-6f0c-448d-ae51-6cef698e6063   82.0  text
# 3  01b4a750-fe75-488d-bdd3-302579e1f5f7   12.0  text
# 4  01d3322e-508f-4eac-93be-f9a16f482b15   12.0  text
# 5  020eeabb-7fc2-4703-810d-a221b583a393  107.0  text
# 6  025caa8c-52eb-474e-a547-a76ca3429508  208.0  text
# 7  036f9db9-7c06-4ecc-acb0-2402c4a4b2b2  117.0  text
# 8  03a6994a-9eb5-44fa-b19f-9026810a1e51  140.0  text
# 9  03dde052-972d-4c15-9cbf-59d4eeb4ab8d  178.0  text
#
#                                      content_preview  \
# 0  include the coefficient of friction, whose val...
# 1  . “A Sound of Thunder.” In The Stories of Ray ...
# 2  . To the often-heard question, “Why can’t we m...
# 3  . In the present instance the colloquial defin...
# 4  manageable. It seems appropriate to call a rea...
# 5  Interest has not been so much in chaos itself ...
# 6  APPENDIX 3 A Brief Dynamical-Systems Glossary ...
# 7  the indicated arithmetic operations. For the t...
# 8  . In fact, the differences more or less steadi...
# 9  . The remarkable thing is that if you choose t...
#
#                                               vector
# 0  [0.009702964685857296, 0.06464481353759766, -0...
# 1  [0.022291049361228943, 0.02111099660396576, -0...
# 2  [0.026930369436740875, 0.04832194373011589, 0....
# 3  [-0.012948527000844479, 0.08835332095623016, -...
# 4  [-0.013000682927668095, 0.06436554342508316, -...
# 5  [-0.019084632396697998, 0.0637802854180336, -0...
# 6  [-0.0009571363916620612, 0.05603436008095741, ...
# 7  [-0.003881527343764901, 0.003138219937682152, ...
# 8  [0.01966932788491249, 0.02676539309322834, -0....
# 9  [-0.015231113880872726, 0.03900129348039627, -...

# %%
fig_pie = px.pie(
    df, 
    names='type', 
    title='Distribution of Text vs. Image Descriptions',
    color_discrete_map={'text': '#636EFA', 'image': '#EF553B'}
)
fig_pie.show()

# %%
fig_hist = px.histogram(
    df, 
    x="page", 
    color="type", 
    nbins=50,
    title="Knowledge Density per Book Page",
    labels={"page": "Page Number", "count": "Chunk Count"},
    color_discrete_map={'text': '#636EFA', 'image': '#FFB6C1'}
)
fig_hist.update_layout(bargap=0.1)
fig_hist.show()

# %%
vectors = list(df['vector'])

pca = PCA(n_components=3)
components = pca.fit_transform(vectors)

df['pca_x'] = components[:, 0]
df['pca_y'] = components[:, 1]
df['pca_z'] = components[:, 2]


fig_3d = px.scatter_3d(
    df,
    x='pca_x',
    y='pca_y',
    z='pca_z',
    color='type',        
    hover_data=['page', 'content_preview'], 
    title='3D Semantic Map of "The Essence of Chaos"',
    opacity=0.7,
    size_max=10,
    color_discrete_map={'text': '#636EFA', 'image': '#FFB6C1'} 
)

fig_3d.update_traces(marker=dict(size=5))
fig_3d.update_layout(
    scene=dict(
        xaxis_title='x',
        yaxis_title='y',
        zaxis_title='z'
    ),
    margin=dict(l=0, r=0, b=0, t=40)
)

fig_3d.show()

# %%
client.close()
# Out:
# {"action":"restapi_management","build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"Shutting down... ","time":"2026-01-18T18:14:20+02:00","version":"1.30.5"}
# {"action":"restapi_management","build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"Stopped serving weaviate at http://127.0.0.1:8079","time":"2026-01-18T18:14:20+02:00","version":"1.30.5"}
# {"action":"telemetry_push","build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"telemetry terminated","payload":"\u0026{MachineID:f883c989-58b6-4e08-8e76-280a75da903c Type:TERMINATE Version:1.30.5 ObjectsCount:678 OS:darwin Arch:arm64 UsedModules:[] CollectionsCount:1}","time":"2026-01-18T18:14:21+02:00"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"closing raft FSM store ...","time":"2026-01-18T18:14:26+02:00"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"shutting down raft sub-system ...","time":"2026-01-18T18:14:26+02:00"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"transferring leadership to another server","time":"2026-01-18T18:14:26+02:00"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","error":"cannot find peer","level":"error","msg":"transferring leadership","time":"2026-01-18T18:14:26+02:00"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"closing raft-net ...","time":"2026-01-18T18:14:26+02:00"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"closing log store ...","time":"2026-01-18T18:14:26+02:00"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"closing data store ...","time":"2026-01-18T18:14:26+02:00"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"closing loaded database ...","time":"2026-01-18T18:14:26+02:00"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"closing raft-rpc client ...","time":"2026-01-18T18:14:26+02:00"}
# {"build_git_commit":"62dcafac32","build_go_version":"go1.24.3","build_image_tag":"HEAD","build_wv_version":"1.30.5","level":"info","msg":"closing raft-rpc server ...","time":"2026-01-18T18:14:26+02:00"}
